# %%
from tensorflow.keras import datasets
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dropout,Dense
from tensorflow.keras.layers import AveragePooling2D, Conv2D

# %%
mnist = datasets.mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
X_train = X_train/255.0
X_test = X_test/255.0

# %%
model4 = Sequential()
model4.add(Flatten(input_shape=[28, 28]))
model4.add(Dropout(0.3))
model4.add(Dense(128, activation='relu'))
model4.add(Dropout(0.3))
model4.add(Dense(128, activation='relu'))
model4.add(Dropout(0.3))
model4.add(Dense(10, activation='softmax'))

# %%
model4.compile(loss='sparse_categorical_crossentropy',optimizer='Adam', metrics=['accuracy'])

# %%
model4.fit(X_train, y_train, epochs=50,validation_split=0.2,batch_size=128)
# Out:
# Epoch 1/50
#   1/375 ━━━━━━━━━━━━━━━━━━━━ 10:50 2s/step - accuracy: 0.1641 - loss: 2.2625
#  49/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3650 - loss: 1.9067
#  94/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4664 - loss: 1.6262
# 147/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5384 - loss: 1.4179
# 195/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5817 - loss: 1.2908
# 250/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6177 - loss: 1.1837
# 304/375 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - accuracy: 0.6447 - loss: 1.1035
# 365/375 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - accuracy: 0.6685 - loss: 1.0322
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7976 - loss: 0.6450 - val_accuracy: 0.9342 - val_loss: 0.2195
# Epoch 2/50
#   1/375 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.8672 - loss: 0.3849
#  52/375 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - accuracy: 0.8869 - loss: 0.3534
# ...

# %%
model4.evaluate(X_test, y_test)
# Out:
#   1/313 ━━━━━━━━━━━━━━━━━━━━ 2:20 450ms/step - accuracy: 0.9688 - loss: 0.0347
#  60/313 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.9810 - loss: 0.0611
# 128/313 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step - accuracy: 0.9761 - loss: 0.0780
# 201/313 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.9751 - loss: 0.0817
# 275/313 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.9759 - loss: 0.0798
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9765 - loss: 0.0782
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9804 - loss: 0.0673
# [0.06732062995433807, 0.980400025844574]

# %%
model5 = Sequential()
model5.add(Conv2D(filters=6, kernel_size=(5,5),activation='tanh', input_shape=(28,28,1)))
model5.add(AveragePooling2D(pool_size =(2, 2), strides =(2, 2)))
model5.add(Conv2D(filters=16, kernel_size=(5,5),activation='tanh'))
model5.add(AveragePooling2D(pool_size =(2, 2), strides =(2, 2)))
model5.add(Flatten())
model5.add(Dense(units=120, activation='tanh'))
model5.add(Dense(units=84, activation='tanh'))
model5.add(Dense(units=10, activation = 'softmax'))

# %%
model5.compile(loss='sparse_categorical_crossentropy',optimizer='Adam', metrics=['accuracy'])

# %%
model5.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 6)      │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_2             │ (None, 12, 12, 6)      │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 8, 8, 16)       │         2,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_3             │ (None, 4, 4, 16)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ...

# %%
model5.fit(X_train, y_train, epochs=50,validation_split=0.2,batch_size=128)
# Out:
# Epoch 1/50
#   1/375 ━━━━━━━━━━━━━━━━━━━━ 11:53 2s/step - accuracy: 0.0625 - loss: 2.3239
#  38/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4568 - loss: 1.7956
#  74/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5752 - loss: 1.4490
# 110/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6379 - loss: 1.2467
# 145/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6775 - loss: 1.1155
# 181/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7064 - loss: 1.0177
# 217/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7284 - loss: 0.9421
# 253/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7458 - loss: 0.8819
# 289/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7601 - loss: 0.8325
# 326/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7724 - loss: 0.7898
# 363/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7829 - loss: 0.7532
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8806 - loss: 0.4116 - val_accuracy: 0.9435 - val_loss: 0.1927
# Epoch 2/50
# ...

# %%
model5.evaluate(X_test, y_test)
# Out:
#   1/313 ━━━━━━━━━━━━━━━━━━━━ 2:47 536ms/step - accuracy: 1.0000 - loss: 0.0041
#  53/313 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - accuracy: 0.9843 - loss: 0.0629
# 103/313 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - accuracy: 0.9827 - loss: 0.0729
# 154/313 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - accuracy: 0.9829 - loss: 0.0752
# 212/313 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - accuracy: 0.9836 - loss: 0.0731
# 265/313 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - accuracy: 0.9843 - loss: 0.0706
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9849 - loss: 0.0679
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9885 - loss: 0.0535
# [0.05347031354904175, 0.9884999990463257]
